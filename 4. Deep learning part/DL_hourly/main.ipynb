# %%
from train import train_model
from test import test_model
import torch
from model import LSTMWithMLP

def main():
    # Train the model
    model = train_model()

    # model = LSTMWithMLP(lstm_input_size=1, output_size=1, num_gaussians=5, mlp_input_dim=11)
    # model.load_state_dict(torch.load('final_model_state.pth'))

    # Test the model
    average_nll_loss, average_mae_loss, average_mape_loss, average_r2_score, average_picp, average_ll = test_model(model)

    # # Output the average losses and R^2 score
    print(f'Average NLL Loss on Test Set: {average_nll_loss:.4f}')
    print(f'Average MAE on Test Set: {average_mae_loss:.4f}')
    print(f'Average MAPE on Test Set: {average_mape_loss:.2f}')
    print(f'R^2 Score on Test Set: {average_r2_score:.4f}')
    print(f'Average PICP on Test Set: {average_picp:.2f}')
    print(f'Average Log-Likelihood on Test Set: {average_ll:.4f}')

    # Save the model state
    torch.save(model.state_dict(), 'final_model_state.pth')
    print("Model state saved successfully.")

if __name__ == "__main__":
    main()
# Out:
# Total windows created: 1
# Total windows created: 2
# Total windows created: 3
# Total windows created: 4
# Total windows created: 5
# Window 0 Epoch 0 Train Loss: 0.1865124157108809, Val Loss: 0.8810307771407657
# Window 0 Epoch 5 Train Loss: -1.2426671658149728, Val Loss: -1.0290724649106182
# Window 0 Epoch 10 Train Loss: -1.6591216465491545, Val Loss: -1.7634893707562074
# Window 1 Epoch 0 Train Loss: -0.014467550387849354, Val Loss: 0.09692050512721495
# Window 1 Epoch 5 Train Loss: -1.4312075298127376, Val Loss: -1.5670052153664398
# Window 1 Epoch 10 Train Loss: -1.704850402683598, Val Loss: -1.8495502208855543
# Window 2 Epoch 0 Train Loss: -0.038428530035141385, Val Loss: 0.8824934735700009
# Window 2 Epoch 5 Train Loss: -1.453502083441644, Val Loss: -1.4141017531022935
# Window 2 Epoch 10 Train Loss: -1.748503489810619, Val Loss: -1.8392287432681365
# Window 3 Epoch 0 Train Loss: 0.4254699846003246, Val Loss: 0.6409876902889522
# Window 3 Epoch 5 Train Loss: -1.382134806054364, Val Loss: -1.3886300724138911
# Window 3 Epoch 10 Train Loss: -1.7627818108157463, Val Loss: -1.8969019911374143
# Window 4 Epoch 0 Train Loss: 0.04341456812873959, Val Loss: 0.6304492677790926
# Window 4 Epoch 5 Train Loss: -1.3008406802794643, Val Loss: -1.394881474257137
# Window 4 Epoch 10 Train Loss: -1.86953465763846, Val Loss: -2.0429836734287847
# Total windows created: 1
# Total windows created: 2
# Total windows created: 3
# Total windows created: 4
# Total windows created: 5
# Average NLL Loss on Test Set: -2.1824
# Average MAE on Test Set: 174.3023
# Average MAPE on Test Set: 15.10
# R^2 Score on Test Set: 0.8872
# Average PICP on Test Set: 74.60
# Average Log-Likelihood on Test Set: -23.0259
# Model state saved successfully.
