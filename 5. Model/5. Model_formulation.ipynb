# %%
import numpy as np
import pandas as pd
from constants import S, I, H, T, station_cost, car_cost, income_per_car, capacity, W, battery_limitation
from TL_graph import time_expanded_location_graphs, process_scenario_data
from data_preprocessing import total_demand_level, mapping_id
from utils import travel_time_func, load_graph_from_pkl, load_and_prepare_graph
import gurobipy as gp
from gurobipy import Model, GRB, quicksum
import osmnx as ox
import networkx as nx

# %%
waiting_arcs, travel_arcs, final_collection_arcs, _ = time_expanded_location_graphs()
dfs = process_scenario_data()

# %%
import gurobipy as gp
from gurobipy import Model, GRB, quicksum
import pandas as pd 

# Initialize the model
m = Model('CSLP')

m.setParam('NodefileStart', 0.5)  # Start writing node files to disk after 0.5GB of memory is used
m.setParam('MIPFocus', 2)  # Focus on finding feasible solutions quickly
m.setParam('Cuts', 3)  # Aggressive cut generation
m.setParam('MIPGap', 0.05)
m.setParam('Presolve', 2)  # Aggressive presolve

"""
Activating this parameter could help in quickly finding good feasible solutions, 
potentially reducing the total solving time as early heuristics can guide the solver to promising regions of the solution space faster.
"""
m.setParam('Heuristics', 0.1)  # Default is 0.05, increase for more heuristic searches
m.setParam('OutputFlag', 1)  # Enable solver output to get detailed logs during optimization
m.setParam('Threads', 32)

# First stage decision variable
y_i = m.addVars(range(I), vtype=GRB.BINARY, name='build_variable')
L_i = m.addVars(range(I), vtype=GRB.INTEGER, name='purchased_car', lb=0, ub=10)

# Second stage decision variale
x_k = m.addVars([(s, k) for s in range(S) for k in range(len(dfs[s]))], vtype=GRB.BINARY, name='accpted_trip')
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-04-08
# Set parameter NodefileStart to value 0.5
# Set parameter MIPFocus to value 2
# Set parameter Cuts to value 3
# Set parameter MIPGap to value 0.05
# Set parameter Presolve to value 2
# Set parameter Heuristics to value 0.1
# Set parameter Threads to value 32

# %%
# Initialize f_ha as a dictionary
f_ha = {}

# Process waiting_arcs and final_collection_arcs
for arc in waiting_arcs + final_collection_arcs:
    s, src, dst = arc  # These are tuples (s, src, dst)
    for h in range(H):
        f_ha[(s, h, arc)] = m.addVar(vtype=GRB.BINARY, name=f'flow_realized_by_car_{s}_{h}_{src}_{dst}')

# Process travel_arcs
for arc in travel_arcs:
    s, k, src, dst = arc  # These are quadruples (s, k, src, dst)
    for h in range(H):
        f_ha[(s, h, arc)] = m.addVar(vtype=GRB.BINARY, name=f'flow_realized_by_car_{s}_{h}_{src}_{dst}')

# %%
x_hk = m.addVars([(s, k, h) for s in range(S) for h in range(H) for k in range(len(dfs[s]))], vtype=GRB.BINARY, name='trip_realized_by_car')

# %%
# Precompute incoming arcs for each (s, i, t)
incoming_arcs_dict = { (s, i, t): [] for s in range(S) for i in range(I) for t in range(T + 1) }
outgoing_arcs_dict = { (s, i, t): [] for s in range(S) for i in range(I) for t in range(T) }

for arc in waiting_arcs:
    s, src, dst = arc
    if (s, dst[0], dst[1]) in incoming_arcs_dict:
        incoming_arcs_dict[(s, dst[0], dst[1])].append(arc)
    if (s, src[0], src[1]) in outgoing_arcs_dict:   
        outgoing_arcs_dict[(s, src[0], src[1])].append(arc)

for arc in travel_arcs:
    s, k, src, dst = arc
    if (s, dst[0], dst[1]) in incoming_arcs_dict:
        incoming_arcs_dict[(s, dst[0], dst[1])].append(arc)
    if (s, src[0], src[1]) in outgoing_arcs_dict:
        outgoing_arcs_dict[(s, src[0], src[1])].append(arc)

# %% [markdown]
# $$
# \text{max} \quad \sum_{s \in S} p_s \sum_{k \in K^s} i_k x_k - \sum_{i \in I} f_i y_i - c \sum_{i \in I} L_i
# $$

# %%
# Objective function: maximize profit
m.setObjective(
    quicksum(
        total_demand_level(s)[1] * quicksum(income_per_car * x_k[s, k] for k in range(len(dfs[s])))
        for s in range(S)
    ) -
    quicksum(station_cost * y_i[i] for i in range(I)) -
    car_cost * quicksum(L_i[i] for i in range(I)),
    GRB.MAXIMIZE
)

# %% [markdown]
# #### Constraint 3.2
# $$\sum_{i\in I}{f_i y_i + c\sum_{i\in I} L_i} \leq W$$
#
# This is the budget constraint, $W$ is the limited budget for all costs.

# %%
# Budget constraints
budget = W
m.addConstr(
    station_cost * quicksum(y_i[i] for i in range(I)) + 
    car_cost * quicksum(L_i[i] for i in range(I)) <= budget,
    name='budget_constraint'
)
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# #### Constraint 3.3
# $$
# \sum_{i \in I} L_i \leq N \tag{1}
# $$

# %%
# # Total number of cars should be fixed as 5 cars
m.addConstr(quicksum(L_i[i] for i in range(I)) <= H, name='total_number_of_cars')
# Out:
# <gurobi.Constr *Awaiting Model Update*>

# %% [markdown]
# ### Constraints 3.4 Battery Limitation

# %%
# Battery limitation
# The maximum operational time is 60 minutes
T_max = battery_limitation

location_id_to_networkx_point = mapping_id()
graphs = load_graph_from_pkl()
travel_time_list = []

for s in range(S):
    for k in range(len(dfs[s])):

        # Get the orgin_id value right now
        origin_id = dfs[s]['starting_point'].iloc[k]

        if origin_id in location_id_to_networkx_point:
            origin = location_id_to_networkx_point[origin_id]
        
        # Get the destination_id value right now
        destination_id = dfs[s]['ending_point'].iloc[k]
        
        if destination_id in location_id_to_networkx_point:
            destination = location_id_to_networkx_point[destination_id]

        hour = dfs[s]['starting_time'].dt.hour.iloc[k]
        G_hour = graphs[hour]

        #Calculate travel time for this trip
        travel_time, _ = travel_time_func(G_hour, origin, destination, hour)

        m.addConstr(travel_time * x_k[s, k] <= T_max, name=f"Battery limitation_s{s}_k{k}")

# %% [markdown]
# ### Constraints 3.5 initial allocation
# $$
# \sum_{h=1}^H \sum_{a \in \delta^{+}\left(i_0\right)} f_a^h = L_i y_i \qquad \quad \forall s \in S, \quad \forall i_0 \in V_0^s
# $$
#
# Constraints \ref{equ:initial allocation} impose restrictions on nodes $i_0$, which represents node $i$ of TLG in the initial state ($t=0$), and $V_0^s$ represents the nodes at the initial time $t=0$ within the scenario $s$. Specifically, the sum of all arcs originating from built charging station $i$, including both waiting arcs and traveling arcs, must equal the initial number of cars at charging station $i$. These constraints can guarantee that each purchased car is first allocated to its corresponding built charging station.

# %%
# Ensure that the initial number of cars at each station equals the outgoing flow at t=0
for i in range(I):
    for s in range(S):
        outgoing_arcs = outgoing_arcs_dict[(s, i, 0)]
        if outgoing_arcs:
            m.addConstr(
                quicksum(f_ha[(s, h, arc)] for h in range(H) for arc in outgoing_arcs if (s, h, arc) in f_ha) == L_i[i] * y_i[i],
                name=f"initial_flow_station_{i}_scenario_{s}"
            )
        else:
            print(f"No outgoing arcs for station {i}, scenario {s} at t=0")

# %% [markdown]
# ### Constraints 3.6
#
# $$\sum_{h=1}^H x_k^h = x_k, \qquad\forall s \in S, k \in K^s $$
#
# It ensures that exactly one car is assigned to each accepted trip.

# %%
# Constraint: one car per accepted trip
for s in range(S):
    for k in range(len(dfs[s])):
        m.addConstr(
            quicksum(x_hk[s, k, h] for h in range(H)) == x_k[s, k], 
            name=f"one_car_per_accepted_trip_s{s}_k{k}"
        )

# %% [markdown]
# ### Constraints 3.7
#
# $$
# \sum_{h \in H} \sum_{k \in K^s : o_k = i, s_k = 0} x_k^h \leq L_i y_i, \qquad \forall i \in I, \quad \forall s \in S
# $$

# %%
# Add the constraint to ensure that the number of trips assigned to each station at t=0 does not exceed the number of cars at that station.
for i in range(I):
    for s in range(S):
        # Create a constraint for each station and scenario at t=0
        m.addConstr(
            quicksum(x_hk[s, k, h] for h in range(H) for k in range(len(dfs[s])) 
                     if dfs[s].iloc[k]['starting_point'] == i and dfs[s].iloc[k]['starting_date'] == 0) <= L_i[i] * y_i[i],
            name=f'trip_assignment_limit_station_{i}_scenario_{s}'
        )

# %% [markdown]
# ### Constrain 3.8
#
# $$\sum_{h=1}^H \sum_{a \in \delta^{+}\left(i_t\right) \cap\left(A_W^s \cup A_C^s\right)} f_a^h \leq C_i y_i \qquad \forall s \in S, \quad\forall i_t \in V^s \backslash\left\{r^s, s^s\right\}$$
#
# It ensures that the quantity of vehicles concurrently parked at station $i$ does not surpass the available number of charging slots at said station.
# Observe that final collection arcs need to be considered on the left-hand side to ensure that the capacity constraints are also met at the end of the planning period.

# %%
# Capacity constraints
for s in range(S):
    for i in range(I):
        # Directly handling the final collection arcs to 'sink'
        final_arc_key = (s, (i, T), 'sink')
        m.addConstr(
            quicksum(f_ha[(s, h, final_arc_key)] for h in range(H) if (s, h, final_arc_key) in f_ha) <= capacity * y_i[i], 
            name=f'capacity_collection_arcs_s{s}_i{i}'
        )

        for t in range(T):
           # Filter and append arcs relevant to the current (s, i, t) 
           outgoing_waiting_arcs = [(s_arc, src, dst) for s_arc, src, dst in waiting_arcs if s_arc == s and src == (i, t)]

           # Filter arcs that are in f_ha
           valid_outgoing_arcs = [arc for arc in outgoing_waiting_arcs if any((s, h, arc) in f_ha for h in range(H))]
           
           # Add constraint
           m.addConstr(quicksum(f_ha[(s, h, arc)] for h in range(H) for arc in valid_outgoing_arcs) <= capacity * y_i[i], name=f'capacity_waiting_arcs_s{s}_i{i}_t{t}')

# %% [markdown]
# ### Constraints 3.9
#
# $$    f^h[\delta^{-}\left(i_t\right)] \leq y_i \quad \forall h \in\{1,2, \ldots, H\}, \quad \forall s \in S, \quad \forall i_t \in V^s \backslash\left\{r^s, s^s\right\}$$
#
# It ensures that car can only enter the built station. It includes waiting arcs (cars only car wait at the built station), and traveling arcs (cars can only park at the built station)

# %%
for s in range(S):
    for i in range(I):
        for t in range(1, T+1):
            # Given s, i, t, a specific waiting arc can be identified
            incoming_arcs = incoming_arcs_dict[(s, i, t)]

            for h in range(H): # Ensure the constraint is applied for each car h
                # Add the combined constraint
                if incoming_arcs:
                    m.addConstr(
                        quicksum(f_ha[(s, h, arc)] for arc in incoming_arcs if (s, h, arc) in f_ha) <= y_i[i],
                        name=f'only_enter_built_station_s{s}_i{i}_t{t}_h{h}'
                    )

# %% [markdown]
# ### Constraint 3.10
#
# $$f^h\left[\delta^{-}\left(i_t\right)\right]=f^h\left[\delta^{+}\left(i_t\right)\right] \quad \forall h \in\{1,2, \ldots, H\}, \quad\forall s \in S, \quad\forall i_t \in V^s \backslash\left\{r^s, s^s\right\}$$
#
# Flow conservation ensures that the route of each car must correspond to a path through the time-expanded location graph for each scenario

# %%
# Flow conservation constraint
for s in range(S):
    for i in range(I):
        for t in range(T):    
            if (i, t) == (i, 0):
                continue # Skip starting point

            incoming_arcs = incoming_arcs_dict[(s, i, t)]
            outgoing_arcs = outgoing_arcs_dict[(s, i, t)]

            for h in range(H):
                m.addConstr(
                    quicksum(f_ha[(s, h, arc)] for arc in incoming_arcs if (s, h, arc) in f_ha) ==
                    quicksum(f_ha[(s, h, arc)] for arc in outgoing_arcs if (s, h, arc) in f_ha),
                    name=f"flow_conservation_s{s}_i{i}_t{t}_h{h}"
                )

# %% [markdown]
# ### Constraint 3.11
#
# $$\sum_{a \in A_{T}^s(k)} f_a^h=x_k^h \quad \forall h \in\{1,2, \ldots, H\}, \quad \forall s \in S, \quad \forall k \in K^s$$
#
# This equation illustrates all action of one car.

# %%
# Precompute travel arcs for each scenario and trip
travel_arcs_per_scenario_trip = {
    (s, k): [arc for arc in travel_arcs if arc[0] == s and arc[1] == k]
    for s in range(S)
    for k in range(len(dfs[s]))
}

# Add constraints to ensure all actions of one car
for s in range(S):
    for k in range(len(dfs[s])):
        relevant_arcs = travel_arcs_per_scenario_trip[(s, k)]
        for h in range(H):
            m.addConstr(
                quicksum(f_ha[(s, h, arc)] for arc in relevant_arcs if (s, h, arc) in f_ha) == x_hk[s, k, h],
                name=f'all_action_one_car_s{s}_k{k}_h{h}'
            )

# %% [markdown]
# ### Constraint 3.12
#
# This equation force each car must fully charge the battery after completing the service.

# %%
# fully_charging_time = 15  # 充电时间为15分钟

# for s in range(S):
#     for k in range(len(dfs[s])):  # 处理每个场景的需求量
#         # 获取场景 s 的所有旅行弧
#         AT_arcs = [(s_arc, k, src, dst) for s_arc, k, src, dst in travel_arcs if s_arc == s]
        
#         if AT_arcs:
#             for h in range(H):
#                 # 获取特定需求 k 的旅行弧
#                 at_arc = AT_arcs[k]
#                 dp = at_arc[3][0]  # 目的地点
#                 et = at_arc[3][1]  # 结束时间

#                 # 为每一个旅行弧添加连续的等待时间弧，直到完全充电时间或达到总时间 T
#                 for minute in range(fully_charging_time):
#                     t_start = et + minute
#                     t_end = t_start + 1

#                     # 如果 t_end 达到或超过 T，则停止添加该旅行弧的更多等待时间弧
#                     if t_end >= T:
#                         break

#                     AW_arc = (s, (dp, t_start), (dp, t_end))  # 定义等待弧

#                     # 检查是否每个等待弧都在 f_ha 中
#                     if (s, h, at_arc) in f_ha and (s, h, AW_arc) in f_ha:
#                         # 为每个旅行弧和对应的等待弧添加流量约束
#                         m.addConstr(f_ha[(s, h, at_arc)] <= f_ha[(s, h, AW_arc)], 
#                                     name=f"charging_constraint_s{s}_k{k}_h{h}_minute{minute}_arct{at_arc}_arcw{AW_arc}")
#                     else:
#                         # 打印出缺失的弧信息，以便进一步调试
#                         if (s, h, at_arc) not in f_ha:
#                             print(f"Travel arc not found in f_ha: {(s, h, at_arc)}")
#                         if (s, h, AW_arc) not in f_ha:
#                             print(f"Waiting arc not found in f_ha: {(s, h, AW_arc)}")

# %%
# Assume fully charging time is 15 mins
fully_charging_time = 1

for s in range(S):
    for k in range(len(dfs)):
        # Define AI_arcs considering all travel arcs for services s.
        AT_arcs = [(s_arc, k, src, dst) for s_arc, k, src, dst in travel_arcs if s_arc == s ] 
        if AT_arcs:
            for h in range(H):
                
                at_arc = AT_arcs[k]
                # sp = at_arc[2][0]
                dp = at_arc[3][0]

                # st = at_arc[2][1]
                et = at_arc[3][1]

                t = et
                t_prime = t + fully_charging_time

                # Finding the corresponding AW_arcs with the updated time t_prime
                AW_arcs = [(s_arc, src, dst) for s_arc, src, dst in waiting_arcs if s_arc == s and src[1] == t and dst[1] == t_prime and src[0] == dp]
                    
                # Now, add the constraint for each matching arc, ensuring we use the unique arc identifiers from all_unique_arcs
                for aw_arc in AW_arcs:
                    if (s, h, at_arc) in f_ha and (s, h, aw_arc) in f_ha:
                        m.addConstr(f_ha[(s, h, at_arc)] <= f_ha[(s, h, aw_arc)], name=f"charging_constraint_s{s}_k{k}_h{h}_arct{at_arc}_arcw{aw_arc}")
                        # print(f'finding the corresponding matching arc_s{s}_h{h}_k{k}')’

# %%
# Before adding constraints
initial_constr_count = m.NumConstrs
m.update()

# %%
# After adding constraints
final_constr_count = m.NumConstrs
print(f'Number of constraints added: {final_constr_count - initial_constr_count}')
# Out:
# Number of constraints added: 484003

# %%
# Solve the model
m.optimize()

# Check optimization status
if m.Status == GRB.OPTIMAL:
    print("Optimization was successful. Printing results.")
    # Initialize total_income
    total_income = 0

    for s in range(S):
        income_per_scenario = 0
        for k in range(len(dfs[s])):
            x_value = x_k[s, k].X  # Get the decision variable value for scenario s and car type k
            income_contribution = income_per_car * x_value
            income_per_scenario += income_contribution
            print(f"x_k[{s}, {k}].X = {x_value}, contributes {income_contribution} to income")

        # Multiply by total demand level for the scenario
        income_per_scenario *= total_demand_level(s)[1]
        total_income += income_per_scenario
        print(f"Total income contribution from scenario {s}: {income_per_scenario}")

    total_station_cost = sum(station_cost * y_i[i].X
                             
                             for i in range(I))
    total_car_cost = car_cost * sum(L_i[i].X for i in range(I))
    
    print(f"Total income: {total_income}")
    print(f"Total station cost: {total_station_cost}")
    print(f"Total car cost: {total_car_cost}")
    
    objective_value = total_income - total_station_cost - total_car_cost
    print(f"Objective value (calculated): {objective_value}")
    print(f"Objective value (from solver): {m.ObjVal}")
    
    for i in range(I):
        if y_i[i].X > 0.5:
            print(f"Build a charging station at location {i} with {L_i[i].X} cars.")

    # Collect and print all f_ha variables with values greater than 0.5
    f_ha_results = []
    for (s, h, arc), var in f_ha.items():
        if var.X > 0.5:
            result = [s, h, arc]
            f_ha_results.append(result)

    # Collect and print all x_k variables with values greater than 0.5
    x_k_results = []
    for (s, k), var in x_k.items():
        if var.X > 0.5:
            result = [s, k]
            x_k_results.append(result)

    # Collect and print all x_hk variables with values greater than 0.5
    x_hk_results = []
    for (s, k, h), var in x_hk.items():
        if var.X > 0.5:
            result = [s, k, h]
            x_hk_results.append(result)

    # Create DataFrame for y_i and L_i
    stations_data = {'Station': [], 'y_i': [], 'L_i': []}
    for i in range(I):
        stations_data['Station'].append(i)
        stations_data['y_i'].append(y_i[i].X)
        stations_data['L_i'].append(L_i[i].X)

    df_stations = pd.DataFrame(stations_data)

else:
    print(f"Optimization issue with status code: {m.Status}")

# For further analysis, you can now search through the results lists
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 11+.0 (22631.2))
#
# CPU model: AMD Ryzen 9 7945HX with Radeon Graphics, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 16 physical cores, 32 logical processors, using up to 32 threads
#
# Optimize a model with 484003 rows, 284798 columns and 1291856 nonzeros
# Model fingerprint: 0xe4f121f2
# Model has 125 quadratic constraints
# Variable types: 0 continuous, 284798 integer (284773 binary)
# Coefficient statistics:
#   Matrix range     [3e-01, 4e+01]
#   QMatrix range    [1e+00, 1e+00]
#   Objective range  [3e-01, 5e+00]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [3e+01, 8e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 416226 rows and 223977 columns
# Presolve time: 0.41s
# Presolved: 67777 rows, 60821 columns, 283949 nonzeros
# Variable types: 0 continuous, 60821 integer (60821 binary)
# Root relaxation presolve removed 3 rows and 0 columns
# Root relaxation presolved: 35780 rows, 45696 columns, 189072 nonzeros
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing primal log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   1.538782e+04      7s
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      313    3.4067787e+03   0.000000e+00   0.000000e+00      7s
#
# Use crossover to convert LP symmetric solution to basic solution...
#
# Root crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 7s
#
#    25191 PPushes remaining with PInf 0.0000000e+00                 7s
#        0 PPushes remaining with PInf 0.0000000e+00                 7s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 5.4353530e+03      7s
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    26231    3.4067787e+03   0.000000e+00   5.435353e+03      7s
#    26281    3.4067787e+03   0.000000e+00   0.000000e+00      7s
#    26281    3.4067787e+03   0.000000e+00   0.000000e+00      7s
#
# Root relaxation: objective 3.406779e+03, 26281 iterations, 0.54 seconds (0.67 work units)
# Total elapsed time = 8.91s (DegenMoves)
# Total elapsed time = 12.31s (DegenMoves)
# Total elapsed time = 16.53s (DegenMoves)
# Total elapsed time = 21.45s (DegenMoves)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 3406.77868    0 4819   -0.00000 3406.77868      -     -   23s
# H    0     0                    2448.3970000 3406.77868  39.1%     -   23s
# H    0     0                    2509.8515600 3406.77868  35.7%     -   23s
# H    0     0                    2934.2153200 3406.77868  16.1%     -   23s
# H    0     0                    3366.9426800 3406.77868  1.18%     -   24s
#
# Cutting planes:
#   Gomory: 32
#   Lift-and-project: 3
#   Cover: 452
#   Implied bound: 55
#   Clique: 480
#   MIR: 33
#   StrongCG: 12
#   Flow cover: 175
#   Zero half: 164
#   Network: 162
#   RLT: 28
#   Relax-and-lift: 26
#   PSD: 1
#
# Explored 1 nodes (158835 simplex iterations) in 25.00 seconds (52.26 work units)
# Thread count was 32 (of 32 available processors)
#
# Solution count 5: 3366.94 2934.22 2509.85 ... -0
#
# Optimal solution found (tolerance 5.00e-02)
# Best objective 3.366942680000e+03, best bound 3.406778680000e+03, gap 1.1832%
# Optimization was successful. Printing results.
# x_k[0, 0].X = 1.0, contributes 20.0 to income
# x_k[0, 1].X = 1.0, contributes 20.0 to income
# x_k[0, 2].X = 1.0, contributes 20.0 to income
# x_k[0, 3].X = -0.0, contributes -0.0 to income
# x_k[0, 4].X = 1.0, contributes 20.0 to income
# x_k[0, 5].X = 1.0, contributes 20.0 to income
# x_k[0, 6].X = 1.0, contributes 20.0 to income
# x_k[0, 7].X = -0.0, contributes -0.0 to income
# x_k[0, 8].X = 1.0, contributes 20.0 to income
# x_k[0, 9].X = 1.0, contributes 20.0 to income
# x_k[0, 10].X = 1.0, contributes 20.0 to income
# x_k[0, 11].X = 1.0, contributes 20.0 to income
# x_k[0, 12].X = 1.0, contributes 20.0 to income
# x_k[0, 13].X = -0.0, contributes -0.0 to income
# x_k[0, 14].X = 1.0, contributes 20.0 to income
# x_k[0, 15].X = 1.0, contributes 20.0 to income
# x_k[0, 16].X = 1.0, contributes 20.0 to income
# x_k[0, 17].X = 1.0, contributes 20.0 to income
# x_k[0, 18].X = -0.0, contributes -0.0 to income
# x_k[0, 19].X = -0.0, contributes -0.0 to income
# x_k[0, 20].X = 1.0, contributes 20.0 to income
# x_k[0, 21].X = 1.0, contributes 20.0 to income
# x_k[0, 22].X = 1.0, contributes 20.0 to income
# x_k[0, 23].X = 1.0, contributes 20.0 to income
# x_k[0, 24].X = 1.0, contributes 20.0 to income
# x_k[0, 25].X = 1.0, contributes 20.0 to income
# x_k[0, 26].X = 1.0, contributes 20.0 to income
# x_k[0, 27].X = 1.0, contributes 20.0 to income
# x_k[0, 28].X = 1.0, contributes 20.0 to income
# x_k[0, 29].X = 1.0, contributes 20.0 to income
# x_k[0, 30].X = 1.0, contributes 20.0 to income
# x_k[0, 31].X = 1.0, contributes 20.0 to income
# x_k[0, 32].X = 1.0, contributes 20.0 to income
# x_k[0, 33].X = 1.0, contributes 20.0 to income
# x_k[0, 34].X = 1.0, contributes 20.0 to income
# x_k[0, 35].X = -0.0, contributes -0.0 to income
# x_k[0, 36].X = -0.0, contributes -0.0 to income
# x_k[0, 37].X = 0.0, contributes 0.0 to income
# x_k[0, 38].X = 1.0, contributes 20.0 to income
# x_k[0, 39].X = 1.0, contributes 20.0 to income
# x_k[0, 40].X = 1.0, contributes 20.0 to income
# x_k[0, 41].X = 1.0, contributes 20.0 to income
# x_k[0, 42].X = 1.0, contributes 20.0 to income
# x_k[0, 43].X = 1.0, contributes 20.0 to income
# x_k[0, 44].X = 1.0, contributes 20.0 to income
# x_k[0, 45].X = 1.0, contributes 20.0 to income
# x_k[0, 46].X = 1.0, contributes 20.0 to income
# x_k[0, 47].X = 1.0, contributes 20.0 to income
# x_k[0, 48].X = 1.0, contributes 20.0 to income
# x_k[0, 49].X = 1.0, contributes 20.0 to income
# x_k[0, 50].X = 1.0, contributes 20.0 to income
# x_k[0, 51].X = -0.0, contributes -0.0 to income
# x_k[0, 52].X = 1.0, contributes 20.0 to income
# x_k[0, 53].X = 1.0, contributes 20.0 to income
# x_k[0, 54].X = 1.0, contributes 20.0 to income
# x_k[0, 55].X = 1.0, contributes 20.0 to income
# x_k[0, 56].X = 1.0, contributes 20.0 to income
# x_k[0, 57].X = 1.0, contributes 20.0 to income
# x_k[0, 58].X = 1.0, contributes 20.0 to income
# x_k[0, 59].X = 1.0, contributes 20.0 to income
# x_k[0, 60].X = 1.0, contributes 20.0 to income
# x_k[0, 61].X = 1.0, contributes 20.0 to income
# x_k[0, 62].X = 1.0, contributes 20.0 to income
# x_k[0, 63].X = 1.0, contributes 20.0 to income
# x_k[0, 64].X = 1.0, contributes 20.0 to income
# x_k[0, 65].X = 1.0, contributes 20.0 to income
# x_k[0, 66].X = 1.0, contributes 20.0 to income
# x_k[0, 67].X = 1.0, contributes 20.0 to income
# x_k[0, 68].X = 1.0, contributes 20.0 to income
# x_k[0, 69].X = 1.0, contributes 20.0 to income
# x_k[0, 70].X = 1.0, contributes 20.0 to income
# x_k[0, 71].X = 1.0, contributes 20.0 to income
# x_k[0, 72].X = 1.0, contributes 20.0 to income
# x_k[0, 73].X = 1.0, contributes 20.0 to income
# x_k[0, 74].X = 1.0, contributes 20.0 to income
# x_k[0, 75].X = 1.0, contributes 20.0 to income
# x_k[0, 76].X = 1.0, contributes 20.0 to income
# x_k[0, 77].X = 1.0, contributes 20.0 to income
# x_k[0, 78].X = 1.0, contributes 20.0 to income
# x_k[0, 79].X = 1.0, contributes 20.0 to income
# x_k[0, 80].X = 1.0, contributes 20.0 to income
# x_k[0, 81].X = 1.0, contributes 20.0 to income
# x_k[0, 82].X = 1.0, contributes 20.0 to income
# x_k[0, 83].X = 1.0, contributes 20.0 to income
# x_k[0, 84].X = 1.0, contributes 20.0 to income
# x_k[0, 85].X = 1.0, contributes 20.0 to income
# x_k[0, 86].X = 1.0, contributes 20.0 to income
# x_k[0, 87].X = 1.0, contributes 20.0 to income
# x_k[0, 88].X = 1.0, contributes 20.0 to income
# x_k[0, 89].X = 1.0, contributes 20.0 to income
# x_k[0, 90].X = 1.0, contributes 20.0 to income
# x_k[0, 91].X = -0.0, contributes -0.0 to income
# x_k[0, 92].X = 1.0, contributes 20.0 to income
# x_k[0, 93].X = 1.0, contributes 20.0 to income
# x_k[0, 94].X = 1.0, contributes 20.0 to income
# x_k[0, 95].X = 1.0, contributes 20.0 to income
# x_k[0, 96].X = 1.0, contributes 20.0 to income
# x_k[0, 97].X = 1.0, contributes 20.0 to income
# x_k[0, 98].X = 1.0, contributes 20.0 to income
# x_k[0, 99].X = 1.0, contributes 20.0 to income
# x_k[0, 100].X = 1.0, contributes 20.0 to income
# x_k[0, 101].X = 1.0, contributes 20.0 to income
# x_k[0, 102].X = 1.0, contributes 20.0 to income
# x_k[0, 103].X = 1.0, contributes 20.0 to income
# x_k[0, 104].X = -0.0, contributes -0.0 to income
# x_k[0, 105].X = 1.0, contributes 20.0 to income
# x_k[0, 106].X = 1.0, contributes 20.0 to income
# x_k[0, 107].X = 1.0, contributes 20.0 to income
# x_k[0, 108].X = 1.0, contributes 20.0 to income
# x_k[0, 109].X = 1.0, contributes 20.0 to income
# x_k[0, 110].X = 1.0, contributes 20.0 to income
# x_k[0, 111].X = 1.0, contributes 20.0 to income
# x_k[0, 112].X = -0.0, contributes -0.0 to income
# x_k[0, 113].X = 1.0, contributes 20.0 to income
# x_k[0, 114].X = 1.0, contributes 20.0 to income
# x_k[0, 115].X = -0.0, contributes -0.0 to income
# x_k[0, 116].X = 1.0, contributes 20.0 to income
# x_k[0, 117].X = 1.0, contributes 20.0 to income
# x_k[0, 118].X = 1.0, contributes 20.0 to income
# x_k[0, 119].X = 1.0, contributes 20.0 to income
# x_k[0, 120].X = 1.0, contributes 20.0 to income
# x_k[0, 121].X = 1.0, contributes 20.0 to income
# x_k[0, 122].X = 1.0, contributes 20.0 to income
# x_k[0, 123].X = 1.0, contributes 20.0 to income
# x_k[0, 124].X = 1.0, contributes 20.0 to income
# x_k[0, 125].X = 1.0, contributes 20.0 to income
# x_k[0, 126].X = 1.0, contributes 20.0 to income
# x_k[0, 127].X = 1.0, contributes 20.0 to income
# x_k[0, 128].X = 1.0, contributes 20.0 to income
# x_k[0, 129].X = 1.0, contributes 20.0 to income
# x_k[0, 130].X = 1.0, contributes 20.0 to income
# x_k[0, 131].X = 1.0, contributes 20.0 to income
# x_k[0, 132].X = 1.0, contributes 20.0 to income
# x_k[0, 133].X = -0.0, contributes -0.0 to income
# x_k[0, 134].X = 1.0, contributes 20.0 to income
# x_k[0, 135].X = 1.0, contributes 20.0 to income
# x_k[0, 136].X = 1.0, contributes 20.0 to income
# x_k[0, 137].X = 1.0, contributes 20.0 to income
# x_k[0, 138].X = 0.0, contributes 0.0 to income
# x_k[0, 139].X = 1.0, contributes 20.0 to income
# x_k[0, 140].X = 1.0, contributes 20.0 to income
# x_k[0, 141].X = -0.0, contributes -0.0 to income
# x_k[0, 142].X = 1.0, contributes 20.0 to income
# x_k[0, 143].X = -0.0, contributes -0.0 to income
# x_k[0, 144].X = 1.0, contributes 20.0 to income
# x_k[0, 145].X = 1.0, contributes 20.0 to income
# x_k[0, 146].X = 1.0, contributes 20.0 to income
# x_k[0, 147].X = 1.0, contributes 20.0 to income
# x_k[0, 148].X = 1.0, contributes 20.0 to income
# x_k[0, 149].X = 1.0, contributes 20.0 to income
# x_k[0, 150].X = 1.0, contributes 20.0 to income
# x_k[0, 151].X = 1.0, contributes 20.0 to income
# x_k[0, 152].X = 1.0, contributes 20.0 to income
# x_k[0, 153].X = 1.0, contributes 20.0 to income
# x_k[0, 154].X = 1.0, contributes 20.0 to income
# x_k[0, 155].X = 1.0, contributes 20.0 to income
# x_k[0, 156].X = -0.0, contributes -0.0 to income
# x_k[0, 157].X = 1.0, contributes 20.0 to income
# x_k[0, 158].X = 1.0, contributes 20.0 to income
# x_k[0, 159].X = 1.0, contributes 20.0 to income
# x_k[0, 160].X = 1.0, contributes 20.0 to income
# x_k[0, 161].X = 1.0, contributes 20.0 to income
# x_k[0, 162].X = 1.0, contributes 20.0 to income
# x_k[0, 163].X = 1.0, contributes 20.0 to income
# x_k[0, 164].X = 1.0, contributes 20.0 to income
# x_k[0, 165].X = 1.0, contributes 20.0 to income
# x_k[0, 166].X = 1.0, contributes 20.0 to income
# x_k[0, 167].X = 1.0, contributes 20.0 to income
# x_k[0, 168].X = 1.0, contributes 20.0 to income
# x_k[0, 169].X = 1.0, contributes 20.0 to income
# x_k[0, 170].X = 1.0, contributes 20.0 to income
# x_k[0, 171].X = 1.0, contributes 20.0 to income
# x_k[0, 172].X = 1.0, contributes 20.0 to income
# x_k[0, 173].X = 1.0, contributes 20.0 to income
# x_k[0, 174].X = 1.0, contributes 20.0 to income
# x_k[0, 175].X = 1.0, contributes 20.0 to income
# x_k[0, 176].X = -0.0, contributes -0.0 to income
# x_k[0, 177].X = 1.0, contributes 20.0 to income
# x_k[0, 178].X = 1.0, contributes 20.0 to income
# x_k[0, 179].X = 1.0, contributes 20.0 to income
# x_k[0, 180].X = -0.0, contributes -0.0 to income
# x_k[0, 181].X = 1.0, contributes 20.0 to income
# x_k[0, 182].X = 1.0, contributes 20.0 to income
# x_k[0, 183].X = 0.0, contributes 0.0 to income
# x_k[0, 184].X = 1.0, contributes 20.0 to income
# x_k[0, 185].X = 1.0, contributes 20.0 to income
# x_k[0, 186].X = 1.0, contributes 20.0 to income
# x_k[0, 187].X = -0.0, contributes -0.0 to income
# x_k[0, 188].X = 1.0, contributes 20.0 to income
# x_k[0, 189].X = 1.0, contributes 20.0 to income
# x_k[0, 190].X = 1.0, contributes 20.0 to income
# x_k[0, 191].X = -0.0, contributes -0.0 to income
# x_k[0, 192].X = 1.0, contributes 20.0 to income
# x_k[0, 193].X = 1.0, contributes 20.0 to income
# x_k[0, 194].X = 1.0, contributes 20.0 to income
# x_k[0, 195].X = 1.0, contributes 20.0 to income
# x_k[0, 196].X = 1.0, contributes 20.0 to income
# x_k[0, 197].X = 1.0, contributes 20.0 to income
# x_k[0, 198].X = 1.0, contributes 20.0 to income
# x_k[0, 199].X = 1.0, contributes 20.0 to income
# x_k[0, 200].X = 1.0, contributes 20.0 to income
# x_k[0, 201].X = 1.0, contributes 20.0 to income
# x_k[0, 202].X = 1.0, contributes 20.0 to income
# x_k[0, 203].X = 1.0, contributes 20.0 to income
# x_k[0, 204].X = 1.0, contributes 20.0 to income
# x_k[0, 205].X = 1.0, contributes 20.0 to income
# x_k[0, 206].X = 1.0, contributes 20.0 to income
# x_k[0, 207].X = -0.0, contributes -0.0 to income
# x_k[0, 208].X = 1.0, contributes 20.0 to income
# x_k[0, 209].X = 1.0, contributes 20.0 to income
# x_k[0, 210].X = 0.0, contributes 0.0 to income
# x_k[0, 211].X = 1.0, contributes 20.0 to income
# x_k[0, 212].X = 1.0, contributes 20.0 to income
# x_k[0, 213].X = 1.0, contributes 20.0 to income
# x_k[0, 214].X = 0.0, contributes 0.0 to income
# x_k[0, 215].X = 1.0, contributes 20.0 to income
# x_k[0, 216].X = 1.0, contributes 20.0 to income
# x_k[0, 217].X = 1.0, contributes 20.0 to income
# x_k[0, 218].X = 1.0, contributes 20.0 to income
# x_k[0, 219].X = 1.0, contributes 20.0 to income
# x_k[0, 220].X = 1.0, contributes 20.0 to income
# x_k[0, 221].X = 1.0, contributes 20.0 to income
# Total income contribution from scenario 0: 926.54688
# x_k[1, 0].X = 1.0, contributes 20.0 to income
# x_k[1, 1].X = 1.0, contributes 20.0 to income
# x_k[1, 2].X = 1.0, contributes 20.0 to income
# x_k[1, 3].X = -0.0, contributes -0.0 to income
# x_k[1, 4].X = 1.0, contributes 20.0 to income
# x_k[1, 5].X = 1.0, contributes 20.0 to income
# x_k[1, 6].X = 1.0, contributes 20.0 to income
# x_k[1, 7].X = 1.0, contributes 20.0 to income
# x_k[1, 8].X = 1.0, contributes 20.0 to income
# x_k[1, 9].X = 1.0, contributes 20.0 to income
# x_k[1, 10].X = 1.0, contributes 20.0 to income
# x_k[1, 11].X = 1.0, contributes 20.0 to income
# x_k[1, 12].X = 1.0, contributes 20.0 to income
# x_k[1, 13].X = 0.0, contributes 0.0 to income
# x_k[1, 14].X = 1.0, contributes 20.0 to income
# x_k[1, 15].X = 1.0, contributes 20.0 to income
# x_k[1, 16].X = 1.0, contributes 20.0 to income
# x_k[1, 17].X = 1.0, contributes 20.0 to income
# x_k[1, 18].X = -0.0, contributes -0.0 to income
# x_k[1, 19].X = 1.0, contributes 20.0 to income
# x_k[1, 20].X = 1.0, contributes 20.0 to income
# x_k[1, 21].X = 1.0, contributes 20.0 to income
# x_k[1, 22].X = 1.0, contributes 20.0 to income
# x_k[1, 23].X = 1.0, contributes 20.0 to income
# x_k[1, 24].X = 1.0, contributes 20.0 to income
# x_k[1, 25].X = 1.0, contributes 20.0 to income
# x_k[1, 26].X = 1.0, contributes 20.0 to income
# x_k[1, 27].X = 1.0, contributes 20.0 to income
# x_k[1, 28].X = 1.0, contributes 20.0 to income
# x_k[1, 29].X = 1.0, contributes 20.0 to income
# x_k[1, 30].X = 1.0, contributes 20.0 to income
# x_k[1, 31].X = 1.0, contributes 20.0 to income
# x_k[1, 32].X = 1.0, contributes 20.0 to income
# x_k[1, 33].X = 1.0, contributes 20.0 to income
# x_k[1, 34].X = 1.0, contributes 20.0 to income
# x_k[1, 35].X = -0.0, contributes -0.0 to income
# x_k[1, 36].X = -0.0, contributes -0.0 to income
# x_k[1, 37].X = -0.0, contributes -0.0 to income
# x_k[1, 38].X = 1.0, contributes 20.0 to income
# x_k[1, 39].X = 1.0, contributes 20.0 to income
# x_k[1, 40].X = 1.0, contributes 20.0 to income
# x_k[1, 41].X = 1.0, contributes 20.0 to income
# x_k[1, 42].X = 1.0, contributes 20.0 to income
# x_k[1, 43].X = 1.0, contributes 20.0 to income
# x_k[1, 44].X = 1.0, contributes 20.0 to income
# x_k[1, 45].X = 1.0, contributes 20.0 to income
# x_k[1, 46].X = 1.0, contributes 20.0 to income
# x_k[1, 47].X = 1.0, contributes 20.0 to income
# x_k[1, 48].X = 1.0, contributes 20.0 to income
# x_k[1, 49].X = 1.0, contributes 20.0 to income
# x_k[1, 50].X = 1.0, contributes 20.0 to income
# x_k[1, 51].X = 1.0, contributes 20.0 to income
# x_k[1, 52].X = 1.0, contributes 20.0 to income
# x_k[1, 53].X = 1.0, contributes 20.0 to income
# x_k[1, 54].X = 1.0, contributes 20.0 to income
# x_k[1, 55].X = 1.0, contributes 20.0 to income
# x_k[1, 56].X = 1.0, contributes 20.0 to income
# x_k[1, 57].X = 1.0, contributes 20.0 to income
# x_k[1, 58].X = 1.0, contributes 20.0 to income
# x_k[1, 59].X = 1.0, contributes 20.0 to income
# x_k[1, 60].X = 1.0, contributes 20.0 to income
# x_k[1, 61].X = 1.0, contributes 20.0 to income
# x_k[1, 62].X = 1.0, contributes 20.0 to income
# x_k[1, 63].X = 1.0, contributes 20.0 to income
# x_k[1, 64].X = 1.0, contributes 20.0 to income
# x_k[1, 65].X = 1.0, contributes 20.0 to income
# x_k[1, 66].X = 1.0, contributes 20.0 to income
# x_k[1, 67].X = 1.0, contributes 20.0 to income
# x_k[1, 68].X = 1.0, contributes 20.0 to income
# x_k[1, 69].X = 1.0, contributes 20.0 to income
# x_k[1, 70].X = 1.0, contributes 20.0 to income
# x_k[1, 71].X = 1.0, contributes 20.0 to income
# x_k[1, 72].X = 1.0, contributes 20.0 to income
# x_k[1, 73].X = 1.0, contributes 20.0 to income
# x_k[1, 74].X = 1.0, contributes 20.0 to income
# x_k[1, 75].X = 1.0, contributes 20.0 to income
# x_k[1, 76].X = 1.0, contributes 20.0 to income
# x_k[1, 77].X = 1.0, contributes 20.0 to income
# x_k[1, 78].X = 1.0, contributes 20.0 to income
# x_k[1, 79].X = 1.0, contributes 20.0 to income
# x_k[1, 80].X = 1.0, contributes 20.0 to income
# x_k[1, 81].X = 1.0, contributes 20.0 to income
# x_k[1, 82].X = 1.0, contributes 20.0 to income
# x_k[1, 83].X = 1.0, contributes 20.0 to income
# x_k[1, 84].X = 1.0, contributes 20.0 to income
# x_k[1, 85].X = 1.0, contributes 20.0 to income
# x_k[1, 86].X = 1.0, contributes 20.0 to income
# x_k[1, 87].X = -0.0, contributes -0.0 to income
# x_k[1, 88].X = 1.0, contributes 20.0 to income
# x_k[1, 89].X = 1.0, contributes 20.0 to income
# x_k[1, 90].X = 1.0, contributes 20.0 to income
# x_k[1, 91].X = -0.0, contributes -0.0 to income
# x_k[1, 92].X = 1.0, contributes 20.0 to income
# x_k[1, 93].X = 1.0, contributes 20.0 to income
# x_k[1, 94].X = 1.0, contributes 20.0 to income
# x_k[1, 95].X = 1.0, contributes 20.0 to income
# x_k[1, 96].X = 1.0, contributes 20.0 to income
# x_k[1, 97].X = 1.0, contributes 20.0 to income
# x_k[1, 98].X = 1.0, contributes 20.0 to income
# x_k[1, 99].X = 0.0, contributes 0.0 to income
# x_k[1, 100].X = 1.0, contributes 20.0 to income
# x_k[1, 101].X = 1.0, contributes 20.0 to income
# x_k[1, 102].X = 1.0, contributes 20.0 to income
# x_k[1, 103].X = 1.0, contributes 20.0 to income
# x_k[1, 104].X = -0.0, contributes -0.0 to income
# x_k[1, 105].X = 1.0, contributes 20.0 to income
# x_k[1, 106].X = 1.0, contributes 20.0 to income
# x_k[1, 107].X = 1.0, contributes 20.0 to income
# x_k[1, 108].X = 0.0, contributes 0.0 to income
# x_k[1, 109].X = 1.0, contributes 20.0 to income
# x_k[1, 110].X = 1.0, contributes 20.0 to income
# x_k[1, 111].X = 1.0, contributes 20.0 to income
# x_k[1, 112].X = -0.0, contributes -0.0 to income
# x_k[1, 113].X = 1.0, contributes 20.0 to income
# x_k[1, 114].X = 1.0, contributes 20.0 to income
# x_k[1, 115].X = 0.0, contributes 0.0 to income
# x_k[1, 116].X = 1.0, contributes 20.0 to income
# x_k[1, 117].X = 1.0, contributes 20.0 to income
# x_k[1, 118].X = 1.0, contributes 20.0 to income
# x_k[1, 119].X = 1.0, contributes 20.0 to income
# x_k[1, 120].X = 1.0, contributes 20.0 to income
# x_k[1, 121].X = 1.0, contributes 20.0 to income
# x_k[1, 122].X = 1.0, contributes 20.0 to income
# x_k[1, 123].X = 1.0, contributes 20.0 to income
# x_k[1, 124].X = 1.0, contributes 20.0 to income
# x_k[1, 125].X = 1.0, contributes 20.0 to income
# x_k[1, 126].X = 1.0, contributes 20.0 to income
# x_k[1, 127].X = 1.0, contributes 20.0 to income
# x_k[1, 128].X = 1.0, contributes 20.0 to income
# x_k[1, 129].X = 1.0, contributes 20.0 to income
# x_k[1, 130].X = 1.0, contributes 20.0 to income
# x_k[1, 131].X = 1.0, contributes 20.0 to income
# x_k[1, 132].X = 1.0, contributes 20.0 to income
# x_k[1, 133].X = -0.0, contributes -0.0 to income
# x_k[1, 134].X = 1.0, contributes 20.0 to income
# x_k[1, 135].X = 1.0, contributes 20.0 to income
# x_k[1, 136].X = 1.0, contributes 20.0 to income
# x_k[1, 137].X = 1.0, contributes 20.0 to income
# x_k[1, 138].X = 0.0, contributes 0.0 to income
# x_k[1, 139].X = 1.0, contributes 20.0 to income
# x_k[1, 140].X = 1.0, contributes 20.0 to income
# x_k[1, 141].X = 1.0, contributes 20.0 to income
# x_k[1, 142].X = 1.0, contributes 20.0 to income
# x_k[1, 143].X = 1.0, contributes 20.0 to income
# x_k[1, 144].X = 1.0, contributes 20.0 to income
# x_k[1, 145].X = 1.0, contributes 20.0 to income
# x_k[1, 146].X = 1.0, contributes 20.0 to income
# x_k[1, 147].X = 1.0, contributes 20.0 to income
# x_k[1, 148].X = 1.0, contributes 20.0 to income
# x_k[1, 149].X = 1.0, contributes 20.0 to income
# x_k[1, 150].X = 1.0, contributes 20.0 to income
# x_k[1, 151].X = 1.0, contributes 20.0 to income
# x_k[1, 152].X = 1.0, contributes 20.0 to income
# x_k[1, 153].X = 1.0, contributes 20.0 to income
# x_k[1, 154].X = 1.0, contributes 20.0 to income
# x_k[1, 155].X = 1.0, contributes 20.0 to income
# x_k[1, 156].X = -0.0, contributes -0.0 to income
# x_k[1, 157].X = 1.0, contributes 20.0 to income
# x_k[1, 158].X = 1.0, contributes 20.0 to income
# x_k[1, 159].X = 1.0, contributes 20.0 to income
# x_k[1, 160].X = 1.0, contributes 20.0 to income
# x_k[1, 161].X = 1.0, contributes 20.0 to income
# x_k[1, 162].X = 1.0, contributes 20.0 to income
# x_k[1, 163].X = 1.0, contributes 20.0 to income
# x_k[1, 164].X = 1.0, contributes 20.0 to income
# x_k[1, 165].X = 1.0, contributes 20.0 to income
# x_k[1, 166].X = 1.0, contributes 20.0 to income
# x_k[1, 167].X = 1.0, contributes 20.0 to income
# x_k[1, 168].X = 1.0, contributes 20.0 to income
# x_k[1, 169].X = 1.0, contributes 20.0 to income
# x_k[1, 170].X = 1.0, contributes 20.0 to income
# x_k[1, 171].X = 1.0, contributes 20.0 to income
# x_k[1, 172].X = 1.0, contributes 20.0 to income
# x_k[1, 173].X = 1.0, contributes 20.0 to income
# x_k[1, 174].X = 1.0, contributes 20.0 to income
# x_k[1, 175].X = 1.0, contributes 20.0 to income
# x_k[1, 176].X = -0.0, contributes -0.0 to income
# x_k[1, 177].X = 1.0, contributes 20.0 to income
# x_k[1, 178].X = 1.0, contributes 20.0 to income
# x_k[1, 179].X = 1.0, contributes 20.0 to income
# x_k[1, 180].X = -0.0, contributes -0.0 to income
# x_k[1, 181].X = 0.0, contributes 0.0 to income
# x_k[1, 182].X = 1.0, contributes 20.0 to income
# x_k[1, 183].X = -0.0, contributes -0.0 to income
# x_k[1, 184].X = 1.0, contributes 20.0 to income
# x_k[1, 185].X = 1.0, contributes 20.0 to income
# x_k[1, 186].X = 1.0, contributes 20.0 to income
# x_k[1, 187].X = -0.0, contributes -0.0 to income
# x_k[1, 188].X = 1.0, contributes 20.0 to income
# x_k[1, 189].X = 1.0, contributes 20.0 to income
# x_k[1, 190].X = 1.0, contributes 20.0 to income
# x_k[1, 191].X = -0.0, contributes -0.0 to income
# x_k[1, 192].X = 1.0, contributes 20.0 to income
# x_k[1, 193].X = 1.0, contributes 20.0 to income
# x_k[1, 194].X = 1.0, contributes 20.0 to income
# x_k[1, 195].X = 1.0, contributes 20.0 to income
# x_k[1, 196].X = 1.0, contributes 20.0 to income
# x_k[1, 197].X = 1.0, contributes 20.0 to income
# x_k[1, 198].X = 1.0, contributes 20.0 to income
# x_k[1, 199].X = 1.0, contributes 20.0 to income
# x_k[1, 200].X = 1.0, contributes 20.0 to income
# x_k[1, 201].X = 1.0, contributes 20.0 to income
# x_k[1, 202].X = 1.0, contributes 20.0 to income
# x_k[1, 203].X = 1.0, contributes 20.0 to income
# x_k[1, 204].X = 1.0, contributes 20.0 to income
# x_k[1, 205].X = 1.0, contributes 20.0 to income
# x_k[1, 206].X = 1.0, contributes 20.0 to income
# x_k[1, 207].X = -0.0, contributes -0.0 to income
# x_k[1, 208].X = 1.0, contributes 20.0 to income
# x_k[1, 209].X = 1.0, contributes 20.0 to income
# x_k[1, 210].X = 1.0, contributes 20.0 to income
# x_k[1, 211].X = 1.0, contributes 20.0 to income
# x_k[1, 212].X = 1.0, contributes 20.0 to income
# x_k[1, 213].X = 1.0, contributes 20.0 to income
# x_k[1, 214].X = 0.0, contributes 0.0 to income
# x_k[1, 215].X = -0.0, contributes -0.0 to income
# x_k[1, 216].X = 1.0, contributes 20.0 to income
# x_k[1, 217].X = 1.0, contributes 20.0 to income
# x_k[1, 218].X = 1.0, contributes 20.0 to income
# x_k[1, 219].X = 1.0, contributes 20.0 to income
# x_k[1, 220].X = 1.0, contributes 20.0 to income
# x_k[1, 221].X = 1.0, contributes 20.0 to income
# x_k[1, 222].X = 1.0, contributes 20.0 to income
# x_k[1, 223].X = 1.0, contributes 20.0 to income
# x_k[1, 224].X = 1.0, contributes 20.0 to income
# x_k[1, 225].X = 1.0, contributes 20.0 to income
# x_k[1, 226].X = 1.0, contributes 20.0 to income
# x_k[1, 227].X = 1.0, contributes 20.0 to income
# x_k[1, 228].X = 1.0, contributes 20.0 to income
# x_k[1, 229].X = 1.0, contributes 20.0 to income
# x_k[1, 230].X = 1.0, contributes 20.0 to income
# x_k[1, 231].X = 1.0, contributes 20.0 to income
# x_k[1, 232].X = 1.0, contributes 20.0 to income
# x_k[1, 233].X = 1.0, contributes 20.0 to income
# x_k[1, 234].X = 1.0, contributes 20.0 to income
# x_k[1, 235].X = 1.0, contributes 20.0 to income
# x_k[1, 236].X = 1.0, contributes 20.0 to income
# x_k[1, 237].X = 1.0, contributes 20.0 to income
# Total income contribution from scenario 1: 1006.91064
# x_k[2, 0].X = 1.0, contributes 20.0 to income
# x_k[2, 1].X = 1.0, contributes 20.0 to income
# x_k[2, 2].X = 1.0, contributes 20.0 to income
# x_k[2, 3].X = 1.0, contributes 20.0 to income
# x_k[2, 4].X = 1.0, contributes 20.0 to income
# x_k[2, 5].X = 1.0, contributes 20.0 to income
# x_k[2, 6].X = 1.0, contributes 20.0 to income
# x_k[2, 7].X = 0.0, contributes 0.0 to income
# x_k[2, 8].X = 1.0, contributes 20.0 to income
# x_k[2, 9].X = 1.0, contributes 20.0 to income
# x_k[2, 10].X = 1.0, contributes 20.0 to income
# x_k[2, 11].X = 1.0, contributes 20.0 to income
# x_k[2, 12].X = 1.0, contributes 20.0 to income
# x_k[2, 13].X = -0.0, contributes -0.0 to income
# x_k[2, 14].X = 1.0, contributes 20.0 to income
# x_k[2, 15].X = 1.0, contributes 20.0 to income
# x_k[2, 16].X = 1.0, contributes 20.0 to income
# x_k[2, 17].X = 1.0, contributes 20.0 to income
# x_k[2, 18].X = 1.0, contributes 20.0 to income
# x_k[2, 19].X = 1.0, contributes 20.0 to income
# x_k[2, 20].X = 1.0, contributes 20.0 to income
# x_k[2, 21].X = 1.0, contributes 20.0 to income
# x_k[2, 22].X = 1.0, contributes 20.0 to income
# x_k[2, 23].X = 1.0, contributes 20.0 to income
# x_k[2, 24].X = 1.0, contributes 20.0 to income
# x_k[2, 25].X = 1.0, contributes 20.0 to income
# x_k[2, 26].X = 1.0, contributes 20.0 to income
# x_k[2, 27].X = 1.0, contributes 20.0 to income
# x_k[2, 28].X = 1.0, contributes 20.0 to income
# x_k[2, 29].X = 1.0, contributes 20.0 to income
# x_k[2, 30].X = 1.0, contributes 20.0 to income
# x_k[2, 31].X = 1.0, contributes 20.0 to income
# x_k[2, 32].X = 1.0, contributes 20.0 to income
# x_k[2, 33].X = 1.0, contributes 20.0 to income
# x_k[2, 34].X = 1.0, contributes 20.0 to income
# x_k[2, 35].X = -0.0, contributes -0.0 to income
# x_k[2, 36].X = -0.0, contributes -0.0 to income
# x_k[2, 37].X = 1.0, contributes 20.0 to income
# x_k[2, 38].X = 1.0, contributes 20.0 to income
# x_k[2, 39].X = 1.0, contributes 20.0 to income
# x_k[2, 40].X = 1.0, contributes 20.0 to income
# x_k[2, 41].X = 1.0, contributes 20.0 to income
# x_k[2, 42].X = 1.0, contributes 20.0 to income
# x_k[2, 43].X = 1.0, contributes 20.0 to income
# x_k[2, 44].X = 1.0, contributes 20.0 to income
# x_k[2, 45].X = 1.0, contributes 20.0 to income
# x_k[2, 46].X = 1.0, contributes 20.0 to income
# x_k[2, 47].X = 1.0, contributes 20.0 to income
# x_k[2, 48].X = 1.0, contributes 20.0 to income
# x_k[2, 49].X = 1.0, contributes 20.0 to income
# x_k[2, 50].X = 1.0, contributes 20.0 to income
# x_k[2, 51].X = 1.0, contributes 20.0 to income
# x_k[2, 52].X = 1.0, contributes 20.0 to income
# x_k[2, 53].X = 1.0, contributes 20.0 to income
# x_k[2, 54].X = 1.0, contributes 20.0 to income
# x_k[2, 55].X = 1.0, contributes 20.0 to income
# x_k[2, 56].X = 1.0, contributes 20.0 to income
# x_k[2, 57].X = 1.0, contributes 20.0 to income
# x_k[2, 58].X = 1.0, contributes 20.0 to income
# x_k[2, 59].X = 1.0, contributes 20.0 to income
# x_k[2, 60].X = 1.0, contributes 20.0 to income
# x_k[2, 61].X = 1.0, contributes 20.0 to income
# x_k[2, 62].X = 1.0, contributes 20.0 to income
# x_k[2, 63].X = 1.0, contributes 20.0 to income
# x_k[2, 64].X = 0.0, contributes 0.0 to income
# x_k[2, 65].X = 1.0, contributes 20.0 to income
# x_k[2, 66].X = 1.0, contributes 20.0 to income
# x_k[2, 67].X = 1.0, contributes 20.0 to income
# x_k[2, 68].X = 1.0, contributes 20.0 to income
# x_k[2, 69].X = 1.0, contributes 20.0 to income
# x_k[2, 70].X = 1.0, contributes 20.0 to income
# x_k[2, 71].X = 1.0, contributes 20.0 to income
# x_k[2, 72].X = 1.0, contributes 20.0 to income
# x_k[2, 73].X = 1.0, contributes 20.0 to income
# x_k[2, 74].X = 1.0, contributes 20.0 to income
# x_k[2, 75].X = 1.0, contributes 20.0 to income
# x_k[2, 76].X = 1.0, contributes 20.0 to income
# x_k[2, 77].X = 1.0, contributes 20.0 to income
# x_k[2, 78].X = 1.0, contributes 20.0 to income
# x_k[2, 79].X = 1.0, contributes 20.0 to income
# x_k[2, 80].X = 1.0, contributes 20.0 to income
# x_k[2, 81].X = 1.0, contributes 20.0 to income
# x_k[2, 82].X = 1.0, contributes 20.0 to income
# x_k[2, 83].X = 1.0, contributes 20.0 to income
# x_k[2, 84].X = 1.0, contributes 20.0 to income
# x_k[2, 85].X = 1.0, contributes 20.0 to income
# x_k[2, 86].X = 1.0, contributes 20.0 to income
# x_k[2, 87].X = 1.0, contributes 20.0 to income
# x_k[2, 88].X = 1.0, contributes 20.0 to income
# x_k[2, 89].X = 1.0, contributes 20.0 to income
# x_k[2, 90].X = 1.0, contributes 20.0 to income
# x_k[2, 91].X = 1.0, contributes 20.0 to income
# x_k[2, 92].X = 1.0, contributes 20.0 to income
# x_k[2, 93].X = 1.0, contributes 20.0 to income
# x_k[2, 94].X = 1.0, contributes 20.0 to income
# x_k[2, 95].X = 1.0, contributes 20.0 to income
# x_k[2, 96].X = 1.0, contributes 20.0 to income
# x_k[2, 97].X = 1.0, contributes 20.0 to income
# x_k[2, 98].X = 1.0, contributes 20.0 to income
# x_k[2, 99].X = 1.0, contributes 20.0 to income
# x_k[2, 100].X = 1.0, contributes 20.0 to income
# x_k[2, 101].X = 1.0, contributes 20.0 to income
# x_k[2, 102].X = 1.0, contributes 20.0 to income
# x_k[2, 103].X = 1.0, contributes 20.0 to income
# x_k[2, 104].X = -0.0, contributes -0.0 to income
# x_k[2, 105].X = 1.0, contributes 20.0 to income
# x_k[2, 106].X = 1.0, contributes 20.0 to income
# x_k[2, 107].X = 1.0, contributes 20.0 to income
# x_k[2, 108].X = 1.0, contributes 20.0 to income
# x_k[2, 109].X = 1.0, contributes 20.0 to income
# x_k[2, 110].X = 1.0, contributes 20.0 to income
# x_k[2, 111].X = 1.0, contributes 20.0 to income
# x_k[2, 112].X = 1.0, contributes 20.0 to income
# x_k[2, 113].X = 1.0, contributes 20.0 to income
# x_k[2, 114].X = 1.0, contributes 20.0 to income
# x_k[2, 115].X = -0.0, contributes -0.0 to income
# x_k[2, 116].X = 1.0, contributes 20.0 to income
# x_k[2, 117].X = 1.0, contributes 20.0 to income
# x_k[2, 118].X = 1.0, contributes 20.0 to income
# x_k[2, 119].X = 1.0, contributes 20.0 to income
# x_k[2, 120].X = 1.0, contributes 20.0 to income
# x_k[2, 121].X = 1.0, contributes 20.0 to income
# x_k[2, 122].X = 1.0, contributes 20.0 to income
# x_k[2, 123].X = 1.0, contributes 20.0 to income
# x_k[2, 124].X = 1.0, contributes 20.0 to income
# x_k[2, 125].X = 1.0, contributes 20.0 to income
# x_k[2, 126].X = 1.0, contributes 20.0 to income
# x_k[2, 127].X = 1.0, contributes 20.0 to income
# x_k[2, 128].X = 1.0, contributes 20.0 to income
# x_k[2, 129].X = 1.0, contributes 20.0 to income
# x_k[2, 130].X = 1.0, contributes 20.0 to income
# x_k[2, 131].X = 1.0, contributes 20.0 to income
# x_k[2, 132].X = 1.0, contributes 20.0 to income
# x_k[2, 133].X = 1.0, contributes 20.0 to income
# x_k[2, 134].X = 1.0, contributes 20.0 to income
# x_k[2, 135].X = 1.0, contributes 20.0 to income
# x_k[2, 136].X = 1.0, contributes 20.0 to income
# x_k[2, 137].X = 1.0, contributes 20.0 to income
# x_k[2, 138].X = 0.0, contributes 0.0 to income
# x_k[2, 139].X = 1.0, contributes 20.0 to income
# x_k[2, 140].X = 1.0, contributes 20.0 to income
# x_k[2, 141].X = 1.0, contributes 20.0 to income
# x_k[2, 142].X = 1.0, contributes 20.0 to income
# x_k[2, 143].X = 1.0, contributes 20.0 to income
# x_k[2, 144].X = 1.0, contributes 20.0 to income
# x_k[2, 145].X = 1.0, contributes 20.0 to income
# x_k[2, 146].X = 1.0, contributes 20.0 to income
# x_k[2, 147].X = 1.0, contributes 20.0 to income
# x_k[2, 148].X = 1.0, contributes 20.0 to income
# x_k[2, 149].X = 1.0, contributes 20.0 to income
# Total income contribution from scenario 2: 516.36312
# x_k[3, 0].X = 1.0, contributes 20.0 to income
# x_k[3, 1].X = 1.0, contributes 20.0 to income
# x_k[3, 2].X = 1.0, contributes 20.0 to income
# x_k[3, 3].X = 1.0, contributes 20.0 to income
# x_k[3, 4].X = 1.0, contributes 20.0 to income
# x_k[3, 5].X = 1.0, contributes 20.0 to income
# x_k[3, 6].X = 1.0, contributes 20.0 to income
# x_k[3, 7].X = 1.0, contributes 20.0 to income
# x_k[3, 8].X = 1.0, contributes 20.0 to income
# x_k[3, 9].X = 1.0, contributes 20.0 to income
# x_k[3, 10].X = 1.0, contributes 20.0 to income
# x_k[3, 11].X = 1.0, contributes 20.0 to income
# x_k[3, 12].X = 1.0, contributes 20.0 to income
# x_k[3, 13].X = -0.0, contributes -0.0 to income
# x_k[3, 14].X = 1.0, contributes 20.0 to income
# x_k[3, 15].X = 1.0, contributes 20.0 to income
# x_k[3, 16].X = 1.0, contributes 20.0 to income
# x_k[3, 17].X = 1.0, contributes 20.0 to income
# x_k[3, 18].X = -0.0, contributes -0.0 to income
# x_k[3, 19].X = 1.0, contributes 20.0 to income
# x_k[3, 20].X = 1.0, contributes 20.0 to income
# x_k[3, 21].X = 1.0, contributes 20.0 to income
# x_k[3, 22].X = 1.0, contributes 20.0 to income
# x_k[3, 23].X = 1.0, contributes 20.0 to income
# x_k[3, 24].X = 1.0, contributes 20.0 to income
# x_k[3, 25].X = 1.0, contributes 20.0 to income
# x_k[3, 26].X = 1.0, contributes 20.0 to income
# x_k[3, 27].X = 1.0, contributes 20.0 to income
# x_k[3, 28].X = 1.0, contributes 20.0 to income
# x_k[3, 29].X = 1.0, contributes 20.0 to income
# x_k[3, 30].X = 1.0, contributes 20.0 to income
# x_k[3, 31].X = 1.0, contributes 20.0 to income
# x_k[3, 32].X = 1.0, contributes 20.0 to income
# x_k[3, 33].X = 1.0, contributes 20.0 to income
# x_k[3, 34].X = 1.0, contributes 20.0 to income
# x_k[3, 35].X = -0.0, contributes -0.0 to income
# x_k[3, 36].X = -0.0, contributes -0.0 to income
# x_k[3, 37].X = 1.0, contributes 20.0 to income
# x_k[3, 38].X = 1.0, contributes 20.0 to income
# x_k[3, 39].X = 1.0, contributes 20.0 to income
# x_k[3, 40].X = 1.0, contributes 20.0 to income
# x_k[3, 41].X = 1.0, contributes 20.0 to income
# x_k[3, 42].X = 1.0, contributes 20.0 to income
# x_k[3, 43].X = 1.0, contributes 20.0 to income
# x_k[3, 44].X = 1.0, contributes 20.0 to income
# x_k[3, 45].X = 1.0, contributes 20.0 to income
# x_k[3, 46].X = 1.0, contributes 20.0 to income
# x_k[3, 47].X = 1.0, contributes 20.0 to income
# x_k[3, 48].X = 1.0, contributes 20.0 to income
# x_k[3, 49].X = 1.0, contributes 20.0 to income
# x_k[3, 50].X = 1.0, contributes 20.0 to income
# x_k[3, 51].X = 1.0, contributes 20.0 to income
# x_k[3, 52].X = 1.0, contributes 20.0 to income
# x_k[3, 53].X = 1.0, contributes 20.0 to income
# x_k[3, 54].X = 1.0, contributes 20.0 to income
# x_k[3, 55].X = 1.0, contributes 20.0 to income
# x_k[3, 56].X = 1.0, contributes 20.0 to income
# x_k[3, 57].X = 1.0, contributes 20.0 to income
# x_k[3, 58].X = 1.0, contributes 20.0 to income
# x_k[3, 59].X = 1.0, contributes 20.0 to income
# x_k[3, 60].X = 1.0, contributes 20.0 to income
# x_k[3, 61].X = 1.0, contributes 20.0 to income
# x_k[3, 62].X = 1.0, contributes 20.0 to income
# x_k[3, 63].X = 1.0, contributes 20.0 to income
# x_k[3, 64].X = -0.0, contributes -0.0 to income
# x_k[3, 65].X = 1.0, contributes 20.0 to income
# x_k[3, 66].X = 1.0, contributes 20.0 to income
# x_k[3, 67].X = 1.0, contributes 20.0 to income
# x_k[3, 68].X = 1.0, contributes 20.0 to income
# x_k[3, 69].X = 1.0, contributes 20.0 to income
# x_k[3, 70].X = 1.0, contributes 20.0 to income
# x_k[3, 71].X = 1.0, contributes 20.0 to income
# x_k[3, 72].X = 1.0, contributes 20.0 to income
# x_k[3, 73].X = 1.0, contributes 20.0 to income
# x_k[3, 74].X = 1.0, contributes 20.0 to income
# x_k[3, 75].X = 1.0, contributes 20.0 to income
# x_k[3, 76].X = 1.0, contributes 20.0 to income
# x_k[3, 77].X = 1.0, contributes 20.0 to income
# x_k[3, 78].X = 1.0, contributes 20.0 to income
# x_k[3, 79].X = 1.0, contributes 20.0 to income
# x_k[3, 80].X = 1.0, contributes 20.0 to income
# x_k[3, 81].X = 1.0, contributes 20.0 to income
# x_k[3, 82].X = 1.0, contributes 20.0 to income
# x_k[3, 83].X = 1.0, contributes 20.0 to income
# x_k[3, 84].X = 1.0, contributes 20.0 to income
# x_k[3, 85].X = 1.0, contributes 20.0 to income
# x_k[3, 86].X = 1.0, contributes 20.0 to income
# x_k[3, 87].X = 1.0, contributes 20.0 to income
# x_k[3, 88].X = 1.0, contributes 20.0 to income
# x_k[3, 89].X = 1.0, contributes 20.0 to income
# x_k[3, 90].X = 1.0, contributes 20.0 to income
# x_k[3, 91].X = 1.0, contributes 20.0 to income
# x_k[3, 92].X = 1.0, contributes 20.0 to income
# x_k[3, 93].X = 1.0, contributes 20.0 to income
# x_k[3, 94].X = 1.0, contributes 20.0 to income
# x_k[3, 95].X = 1.0, contributes 20.0 to income
# x_k[3, 96].X = 1.0, contributes 20.0 to income
# x_k[3, 97].X = 1.0, contributes 20.0 to income
# x_k[3, 98].X = 1.0, contributes 20.0 to income
# x_k[3, 99].X = 1.0, contributes 20.0 to income
# x_k[3, 100].X = 1.0, contributes 20.0 to income
# x_k[3, 101].X = 1.0, contributes 20.0 to income
# x_k[3, 102].X = 1.0, contributes 20.0 to income
# x_k[3, 103].X = 1.0, contributes 20.0 to income
# x_k[3, 104].X = -0.0, contributes -0.0 to income
# x_k[3, 105].X = 1.0, contributes 20.0 to income
# x_k[3, 106].X = 1.0, contributes 20.0 to income
# x_k[3, 107].X = 1.0, contributes 20.0 to income
# x_k[3, 108].X = 1.0, contributes 20.0 to income
# x_k[3, 109].X = 1.0, contributes 20.0 to income
# x_k[3, 110].X = 1.0, contributes 20.0 to income
# x_k[3, 111].X = 1.0, contributes 20.0 to income
# x_k[3, 112].X = 1.0, contributes 20.0 to income
# x_k[3, 113].X = 1.0, contributes 20.0 to income
# x_k[3, 114].X = 1.0, contributes 20.0 to income
# x_k[3, 115].X = 1.0, contributes 20.0 to income
# x_k[3, 116].X = 1.0, contributes 20.0 to income
# x_k[3, 117].X = 1.0, contributes 20.0 to income
# x_k[3, 118].X = 1.0, contributes 20.0 to income
# x_k[3, 119].X = 1.0, contributes 20.0 to income
# x_k[3, 120].X = 1.0, contributes 20.0 to income
# x_k[3, 121].X = 1.0, contributes 20.0 to income
# x_k[3, 122].X = 1.0, contributes 20.0 to income
# x_k[3, 123].X = 1.0, contributes 20.0 to income
# x_k[3, 124].X = 1.0, contributes 20.0 to income
# x_k[3, 125].X = 1.0, contributes 20.0 to income
# x_k[3, 126].X = 1.0, contributes 20.0 to income
# x_k[3, 127].X = 1.0, contributes 20.0 to income
# x_k[3, 128].X = 1.0, contributes 20.0 to income
# x_k[3, 129].X = 1.0, contributes 20.0 to income
# x_k[3, 130].X = 1.0, contributes 20.0 to income
# x_k[3, 131].X = 1.0, contributes 20.0 to income
# x_k[3, 132].X = 1.0, contributes 20.0 to income
# x_k[3, 133].X = 0.0, contributes 0.0 to income
# x_k[3, 134].X = 1.0, contributes 20.0 to income
# x_k[3, 135].X = -0.0, contributes -0.0 to income
# x_k[3, 136].X = 1.0, contributes 20.0 to income
# x_k[3, 137].X = 1.0, contributes 20.0 to income
# x_k[3, 138].X = 0.0, contributes 0.0 to income
# x_k[3, 139].X = 1.0, contributes 20.0 to income
# x_k[3, 140].X = 1.0, contributes 20.0 to income
# x_k[3, 141].X = 1.0, contributes 20.0 to income
# x_k[3, 142].X = 1.0, contributes 20.0 to income
# x_k[3, 143].X = 1.0, contributes 20.0 to income
# x_k[3, 144].X = 1.0, contributes 20.0 to income
# x_k[3, 145].X = 1.0, contributes 20.0 to income
# Total income contribution from scenario 3: 498.18132
# x_k[4, 0].X = 1.0, contributes 20.0 to income
# x_k[4, 1].X = 1.0, contributes 20.0 to income
# x_k[4, 2].X = 1.0, contributes 20.0 to income
# x_k[4, 3].X = 1.0, contributes 20.0 to income
# x_k[4, 4].X = 1.0, contributes 20.0 to income
# x_k[4, 5].X = 1.0, contributes 20.0 to income
# x_k[4, 6].X = 1.0, contributes 20.0 to income
# x_k[4, 7].X = 1.0, contributes 20.0 to income
# x_k[4, 8].X = 1.0, contributes 20.0 to income
# x_k[4, 9].X = 1.0, contributes 20.0 to income
# x_k[4, 10].X = 1.0, contributes 20.0 to income
# x_k[4, 11].X = 1.0, contributes 20.0 to income
# x_k[4, 12].X = 1.0, contributes 20.0 to income
# x_k[4, 13].X = -0.0, contributes -0.0 to income
# x_k[4, 14].X = 1.0, contributes 20.0 to income
# x_k[4, 15].X = 1.0, contributes 20.0 to income
# x_k[4, 16].X = 1.0, contributes 20.0 to income
# x_k[4, 17].X = 1.0, contributes 20.0 to income
# x_k[4, 18].X = 0.0, contributes 0.0 to income
# x_k[4, 19].X = 1.0, contributes 20.0 to income
# x_k[4, 20].X = 1.0, contributes 20.0 to income
# x_k[4, 21].X = 1.0, contributes 20.0 to income
# x_k[4, 22].X = 1.0, contributes 20.0 to income
# x_k[4, 23].X = 1.0, contributes 20.0 to income
# x_k[4, 24].X = 1.0, contributes 20.0 to income
# x_k[4, 25].X = 1.0, contributes 20.0 to income
# x_k[4, 26].X = 1.0, contributes 20.0 to income
# x_k[4, 27].X = 1.0, contributes 20.0 to income
# x_k[4, 28].X = 1.0, contributes 20.0 to income
# x_k[4, 29].X = 1.0, contributes 20.0 to income
# x_k[4, 30].X = 1.0, contributes 20.0 to income
# x_k[4, 31].X = 1.0, contributes 20.0 to income
# x_k[4, 32].X = 1.0, contributes 20.0 to income
# x_k[4, 33].X = 1.0, contributes 20.0 to income
# x_k[4, 34].X = 1.0, contributes 20.0 to income
# x_k[4, 35].X = -0.0, contributes -0.0 to income
# x_k[4, 36].X = -0.0, contributes -0.0 to income
# x_k[4, 37].X = 1.0, contributes 20.0 to income
# x_k[4, 38].X = 1.0, contributes 20.0 to income
# x_k[4, 39].X = 1.0, contributes 20.0 to income
# x_k[4, 40].X = 1.0, contributes 20.0 to income
# x_k[4, 41].X = 1.0, contributes 20.0 to income
# x_k[4, 42].X = 1.0, contributes 20.0 to income
# x_k[4, 43].X = 1.0, contributes 20.0 to income
# x_k[4, 44].X = 1.0, contributes 20.0 to income
# x_k[4, 45].X = 1.0, contributes 20.0 to income
# x_k[4, 46].X = 1.0, contributes 20.0 to income
# x_k[4, 47].X = 1.0, contributes 20.0 to income
# x_k[4, 48].X = 1.0, contributes 20.0 to income
# x_k[4, 49].X = 1.0, contributes 20.0 to income
# x_k[4, 50].X = 1.0, contributes 20.0 to income
# x_k[4, 51].X = 0.0, contributes 0.0 to income
# x_k[4, 52].X = 1.0, contributes 20.0 to income
# x_k[4, 53].X = 1.0, contributes 20.0 to income
# x_k[4, 54].X = 1.0, contributes 20.0 to income
# x_k[4, 55].X = 1.0, contributes 20.0 to income
# x_k[4, 56].X = 1.0, contributes 20.0 to income
# x_k[4, 57].X = 1.0, contributes 20.0 to income
# x_k[4, 58].X = 1.0, contributes 20.0 to income
# x_k[4, 59].X = 1.0, contributes 20.0 to income
# x_k[4, 60].X = 1.0, contributes 20.0 to income
# x_k[4, 61].X = 1.0, contributes 20.0 to income
# x_k[4, 62].X = 1.0, contributes 20.0 to income
# x_k[4, 63].X = 1.0, contributes 20.0 to income
# x_k[4, 64].X = 1.0, contributes 20.0 to income
# x_k[4, 65].X = 1.0, contributes 20.0 to income
# x_k[4, 66].X = 1.0, contributes 20.0 to income
# x_k[4, 67].X = 1.0, contributes 20.0 to income
# x_k[4, 68].X = 1.0, contributes 20.0 to income
# x_k[4, 69].X = 1.0, contributes 20.0 to income
# x_k[4, 70].X = 1.0, contributes 20.0 to income
# x_k[4, 71].X = 1.0, contributes 20.0 to income
# x_k[4, 72].X = 1.0, contributes 20.0 to income
# x_k[4, 73].X = 1.0, contributes 20.0 to income
# x_k[4, 74].X = 1.0, contributes 20.0 to income
# x_k[4, 75].X = 1.0, contributes 20.0 to income
# x_k[4, 76].X = 1.0, contributes 20.0 to income
# x_k[4, 77].X = 1.0, contributes 20.0 to income
# x_k[4, 78].X = 1.0, contributes 20.0 to income
# x_k[4, 79].X = 1.0, contributes 20.0 to income
# x_k[4, 80].X = 1.0, contributes 20.0 to income
# x_k[4, 81].X = 1.0, contributes 20.0 to income
# x_k[4, 82].X = 1.0, contributes 20.0 to income
# x_k[4, 83].X = 1.0, contributes 20.0 to income
# x_k[4, 84].X = 1.0, contributes 20.0 to income
# x_k[4, 85].X = 1.0, contributes 20.0 to income
# x_k[4, 86].X = 1.0, contributes 20.0 to income
# x_k[4, 87].X = 1.0, contributes 20.0 to income
# x_k[4, 88].X = 1.0, contributes 20.0 to income
# x_k[4, 89].X = 1.0, contributes 20.0 to income
# x_k[4, 90].X = 1.0, contributes 20.0 to income
# x_k[4, 91].X = 1.0, contributes 20.0 to income
# x_k[4, 92].X = 1.0, contributes 20.0 to income
# x_k[4, 93].X = 1.0, contributes 20.0 to income
# x_k[4, 94].X = 1.0, contributes 20.0 to income
# x_k[4, 95].X = 1.0, contributes 20.0 to income
# x_k[4, 96].X = 1.0, contributes 20.0 to income
# x_k[4, 97].X = 1.0, contributes 20.0 to income
# x_k[4, 98].X = 1.0, contributes 20.0 to income
# x_k[4, 99].X = 1.0, contributes 20.0 to income
# x_k[4, 100].X = 1.0, contributes 20.0 to income
# x_k[4, 101].X = 1.0, contributes 20.0 to income
# x_k[4, 102].X = 1.0, contributes 20.0 to income
# x_k[4, 103].X = 1.0, contributes 20.0 to income
# x_k[4, 104].X = -0.0, contributes -0.0 to income
# x_k[4, 105].X = 1.0, contributes 20.0 to income
# x_k[4, 106].X = 1.0, contributes 20.0 to income
# x_k[4, 107].X = 1.0, contributes 20.0 to income
# x_k[4, 108].X = 1.0, contributes 20.0 to income
# x_k[4, 109].X = 1.0, contributes 20.0 to income
# x_k[4, 110].X = 1.0, contributes 20.0 to income
# x_k[4, 111].X = 1.0, contributes 20.0 to income
# x_k[4, 112].X = 0.0, contributes 0.0 to income
# x_k[4, 113].X = 1.0, contributes 20.0 to income
# x_k[4, 114].X = 1.0, contributes 20.0 to income
# x_k[4, 115].X = -0.0, contributes -0.0 to income
# x_k[4, 116].X = 1.0, contributes 20.0 to income
# x_k[4, 117].X = 1.0, contributes 20.0 to income
# x_k[4, 118].X = 1.0, contributes 20.0 to income
# x_k[4, 119].X = 1.0, contributes 20.0 to income
# x_k[4, 120].X = 1.0, contributes 20.0 to income
# x_k[4, 121].X = 1.0, contributes 20.0 to income
# x_k[4, 122].X = 1.0, contributes 20.0 to income
# x_k[4, 123].X = 1.0, contributes 20.0 to income
# x_k[4, 124].X = 1.0, contributes 20.0 to income
# x_k[4, 125].X = 1.0, contributes 20.0 to income
# x_k[4, 126].X = 1.0, contributes 20.0 to income
# x_k[4, 127].X = 1.0, contributes 20.0 to income
# x_k[4, 128].X = 1.0, contributes 20.0 to income
# x_k[4, 129].X = 1.0, contributes 20.0 to income
# x_k[4, 130].X = -0.0, contributes -0.0 to income
# x_k[4, 131].X = 1.0, contributes 20.0 to income
# x_k[4, 132].X = 1.0, contributes 20.0 to income
# x_k[4, 133].X = 1.0, contributes 20.0 to income
# x_k[4, 134].X = 1.0, contributes 20.0 to income
# x_k[4, 135].X = 0.0, contributes 0.0 to income
# x_k[4, 136].X = 1.0, contributes 20.0 to income
# x_k[4, 137].X = 1.0, contributes 20.0 to income
# x_k[4, 138].X = 0.0, contributes 0.0 to income
# x_k[4, 139].X = 1.0, contributes 20.0 to income
# x_k[4, 140].X = 1.0, contributes 20.0 to income
# x_k[4, 141].X = 1.0, contributes 20.0 to income
# x_k[4, 142].X = 1.0, contributes 20.0 to income
# x_k[4, 143].X = 1.0, contributes 20.0 to income
# x_k[4, 144].X = 1.0, contributes 20.0 to income
# x_k[4, 145].X = 1.0, contributes 20.0 to income
# x_k[4, 146].X = 1.0, contributes 20.0 to income
# x_k[4, 147].X = 1.0, contributes 20.0 to income
# x_k[4, 148].X = 1.0, contributes 20.0 to income
# x_k[4, 149].X = 1.0, contributes 20.0 to income
# x_k[4, 150].X = 1.0, contributes 20.0 to income
# x_k[4, 151].X = 1.0, contributes 20.0 to income
# x_k[4, 152].X = 1.0, contributes 20.0 to income
# x_k[4, 153].X = 1.0, contributes 20.0 to income
# x_k[4, 154].X = 1.0, contributes 20.0 to income
# x_k[4, 155].X = 1.0, contributes 20.0 to income
# x_k[4, 156].X = 1.0, contributes 20.0 to income
# x_k[4, 157].X = 1.0, contributes 20.0 to income
# x_k[4, 158].X = 1.0, contributes 20.0 to income
# x_k[4, 159].X = 1.0, contributes 20.0 to income
# x_k[4, 160].X = 1.0, contributes 20.0 to income
# x_k[4, 161].X = 1.0, contributes 20.0 to income
# Total income contribution from scenario 4: 494.18072
# Total income: 3442.18268
# Total station cost: 75.24000000000002
# Total car cost: 0.0
# Objective value (calculated): 3366.9426799999997
# Objective value (from solver): 3366.9426800000047
# Build a charging station at location 1 with -0.0 cars.
# Build a charging station at location 2 with -0.0 cars.
# Build a charging station at location 3 with -0.0 cars.
# Build a charging station at location 4 with -0.0 cars.
# Build a charging station at location 5 with -0.0 cars.
# Build a charging station at location 6 with -0.0 cars.
# Build a charging station at location 7 with -0.0 cars.
# Build a charging station at location 8 with -0.0 cars.
# Build a charging station at location 9 with -0.0 cars.
# Build a charging station at location 10 with -0.0 cars.
# Build a charging station at location 11 with -0.0 cars.
# Build a charging station at location 12 with -0.0 cars.
# Build a charging station at location 13 with -0.0 cars.
# Build a charging station at location 14 with -0.0 cars.
# Build a charging station at location 15 with -0.0 cars.
# Build a charging station at location 17 with -0.0 cars.
# Build a charging station at location 19 with -0.0 cars.
# Build a charging station at location 20 with -0.0 cars.
# Build a charging station at location 21 with -0.0 cars.
# Build a charging station at location 22 with -0.0 cars.
# Build a charging station at location 23 with -0.0 cars.
# Build a charging station at location 24 with -0.0 cars.

# %%
# Profit
print(f'Profit is {total_income}')
# Return on Investment (ROI)
ROI = round(total_income / (total_station_cost + total_car_cost), 4)
print(f'Return on Investment (ROI) is {ROI}')

# Demand Satisfaction Ratio (DSR)
dsr = 0
for s in range(S):
    count = len([item for item in x_k_results if item[0] == s])
    dsr += (count / len(dfs[s])) * total_demand_level[s][1]
    dsr = round(dsr, 4)
print(f'Demand Satisfaction Ratio (DSR) is {dsr}')


# Charging Station Utilization Rate (CSU)
CSU_total = 0

for s in range(S):  # Iterate over each scenario
    scenario_utilization = 0  # Initialize the total utilization for the scenario

    for i in range(I):  # Iterate over each station
        avg_utilization_i = 0  # Initialize average utilization for station i
        
        for t in range(T):  # Iterate over each time period t
            # Filter f_ha_results to find arcs associated with station i at time t in scenario s
            result_fha = [
                item for item in f_ha_results 
                if item[0] == s and len(item[2]) == 3 
                and item[2][1][0] == i and item[2][1][1] == t
            ]
            
            # Calculate the utilization rate at time t for station i
            utilization_rate_t = sum(1 for _ in result_fha) / capacity  # Number of cars at station i at time t divided by capacity
            
            # Accumulate utilization for station i
            avg_utilization_i += utilization_rate_t
        
        # Compute the average utilization for station i over all time periods T
        avg_utilization_i /= T
        
        # Accumulate the utilization for the scenario
        scenario_utilization += avg_utilization_i
    
    # Multiply the scenario utilization by its probability p_s and add to the total CSU
    CSU_total += total_demand_level(s)[1] * scenario_utilization

# Step 2: Print or return the final CSU (Charging Station Utilization)
print(f"Charging Station Utilization (CSU): {CSU_total}")
# Out:
# Profit is 3442.18268
# Return on Investment (ROI) is 45.7494
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 11
#       9 for s in range(S):
#      10     count = len([item for item in x_k_results if item[0] == s])
# ---> 11     dsr += (count / len(dfs[s])) * total_demand_level[s][1]
#      12     dsr = round(dsr, 4)
#      13 print(f'Demand Satisfaction Ratio (DSR) is {dsr}')
#
# TypeError: 'function' object is not subscriptable
