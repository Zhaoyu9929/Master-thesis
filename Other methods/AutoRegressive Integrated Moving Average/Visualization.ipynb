# %%
import pandas as pd
import numpy as np

# %%
path = r"C:\Users\yanzh\Desktop\code_and_data\4. Deep learning part\2015-2019 total trips.csv"
df = pd.read_csv(path)
df
# Out:
#                    date  trip_count_yellow  trip_count_green  total_trips
# 0         2015/1/1 0:00              21258               851        22109
# 1         2015/1/1 1:00              21740               719        22459
# 2         2015/1/1 2:00              17769               699        18468
# 3         2015/1/1 3:00              14430               607        15037
# 4         2015/1/1 4:00               9275               438         9713
# ...                 ...                ...               ...          ...
# 43820  2019/12/31 19:00               8229               284         8513
# 43821  2019/12/31 20:00               9883               278        10161
# 43822  2019/12/31 21:00               8732               259         8991
# 43823  2019/12/31 22:00               6945               207         7152
# 43824  2019/12/31 23:00               5451               142         5593
#
# [43825 rows x 4 columns]

# %%
import pandas as pd
import plotly.express as px

# Assuming df is already defined as your DataFrame
df['date'] = pd.to_datetime(df['date'])  # Ensure the date column is in datetime format

# Create the plot
fig = px.line(df, x='date', y='trip_count_yellow', title='Total Trip Count Over Time')

# Update layout for better scroll functionality
fig.update_layout(
    xaxis=dict(
        rangeslider=dict(
            visible=True
        ),
        type="date"
    )
)

# Show the plot
fig.show()
